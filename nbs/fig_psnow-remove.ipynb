# %%
import datetime
import os
import glob
import gc
import pandas as pd
import xarray as xr
import numpy as np
import geopandas as gpd

import matplotlib as mpl
import matplotlib.pyplot as plt 
from matplotlib import cm
from matplotlib import colors as mcolors
import cmcrameri.cm as ccm

from params import boundaries
from myutil import make_ts, rescale_lists
from dirs import workdir
plt.style.use('science.mplstyle')
projectdir = '/glade/campaign/uwyo/wyom0200/berkeley/'

# %%
domains = ['d01', 'd02']
coordsdict = {}
for domain in domains:
    coordsdict[domain] = xr.open_dataset(f'{workdir}wrfinput_{domain}')

# %%
params = {'vars': ['prec','t2','snow'],
          'states' : ['CA', 'WY'],
          'res': ['45','9','3']}
res_domain = {'3': ['d03','d04'],
               '9' :['d02'],
               '45':['d01']}
domain_state = {'d01':['CA','WY'],
                'd02':['CA','WY'],
                'd03':['CA'],
                'd04':['WY'],}
boundaries = {'d01':{'CA': [43,60,35,68], ## left, right, bottom, top
                     'WY': [68,81,43,63]},
              'd02':{'CA': [44,125,87,251],
                     'WY': [165,230,130,227]},
              'd03':{'CA': [0,-1,0,-1]},
              'd04':{'WY': [0,-1,0,-1]}}
state_res_domain = {'CA': {'45':'d01',
                            '9': 'd02',
                            '3':'d03'},
                     'WY': {'45':'d01',
                            '9': 'd02',
                            '3':'d04'},}
                     
gcms_dict = {'d01': ['cesm2','mpi-esm1-2-lr','cnrm-esm2-1',
                     'ec-earth3-veg','fgoals-g3','ukesm1-0-ll',
                     'canesm5','access-cm2','ec-earth3'],
             'd02': ['cesm2','mpi-esm1-2-lr','cnrm-esm2-1',
                     'ec-earth3-veg','fgoals-g3','ukesm1-0-ll',
                     'canesm5','access-cm2','ec-earth3'],
             'd03': ['ec-earth3-veg'],
             'd04': ['ec-earth3-veg'],}

bc = 'BC'

# %%
partition = np.load('/glade/campaign/uwyo/wyom0200/berkeley/partition_annual.npy',allow_pickle = True).flatten()[0]
alldata = np.load('/glade/campaign/uwyo/wyom0200/berkeley/annual_max_clipped.npy',allow_pickle = True).flatten()[0]

# %%
partitions = []
#  = []
for gcm in gcms_dict['d02']:
    try:
        partition = np.load(f'/glade/campaign/uwyo/wyom0200/berkeley/partition_annual_{gcm}.npy',allow_pickle = True).flatten()[0]
        #alldata = np.load(f'/glade/campaign/uwyo/wyom0112/berkeley/annual_max_clipped_{gcm}.npy',allow_pickle = True).flatten()[0]
        partitions.append(partition)
        #alldatas.append(alldata)
    except:
        print(gcm)
# Out:
# ukesm1-0-ll

# %%
annual_pdd = xr.open_dataset('/glade/campaign/uwyo/wyom0200/berkeley/annual_pdd_d02.nc')
annual_dd = xr.open_dataset('/glade/campaign/uwyo/wyom0200/berkeley/annual_dd_d02.nc')
mygcms = ['cesm2',
 'mpi-esm1-2-lr',
 'cnrm-esm2-1',
 'ec-earth3-veg',
 'fgoals-g3',
 'canesm5',
 'access-cm2',
 'ec-earth3']
years = range(1981,2099)
snowmasks = np.load('/glade/work/mcowherd/snowmasks.npy', allow_pickle = True).flatten()[0]

# %%
def prep_elbow(partition):
    ress = ['45','9']
    ws = 10
    var = 'prec'
    outs = []
    desc = []
    snows = []
    rains = []
    for i,state in enumerate(params['states']):
        for res in ress:
            for j,ptype in enumerate(['snowfall','rainfall']):
                domain = state_res_domain[state][res]
                mask = snowmasks[state][res]
                left, right, bottom, top = boundaries[domain][state]
                tmp = partition[state][res][ptype].sel(lat2d = slice(bottom, top),
                                                                           lon2d = slice(left, right))['prec']
                data = np.nanmean(tmp.where(mask), axis = (1,2))[1:-2]
                outs.append(data)
                desc.append(f'{state}_{res}_{ptype}')                
       
            domain = state_res_domain[state][res]
            mask = snowmasks[state][res]
            left, right, bottom, top = boundaries[domain][state]
            tmpsnow = partition[state][res]['snowfall'].sel(lat2d = slice(bottom, top),
                                                                       lon2d = slice(left, right))['prec']
            tmprain = partition[state][res]['rainfall'].sel(lat2d = slice(bottom, top),
                                                                   lon2d = slice(left, right))['prec']
            snowdata = np.nanmean(tmpsnow.where(mask), axis = (1,2))[1:-2]
            raindata = np.nanmean(tmprain.where(mask), axis = (1,2))[1:-2]
            snows.append(snowdata)
            rains.append(raindata)
    return outs,snows,rains,desc

# %%
ws = 15
resstyles = ['--','-']
alphas = [0.3,0.9]
colors = ["#332288","#88CCEE","#44AA99","#117733","#999933","#DDCC77","#CC6677","#882255","#AA4499"] #,"brown","fd3c06","gray"]]
fig,axs = plt.subplots(2,3, figsize = (17,10))
names = {'CA':'Sierra Nevada', 'WY':'Middle Rockies'}
x1s = []
y1s = []
x2s = []
y2s = []

lines = {}


for k,gcm in enumerate(mygcms):
    partition = partitions[k]
    ress = ['45','9']
    lines[gcm] = {}
    var = 'prec'
    for i,state in enumerate(params['states']):
        lines[gcm][state] = {}
        for l,res in enumerate(ress):
            lines[gcm][state][res] = {}
            for j,ptype in enumerate(['snowfall','rainfall']):
                ax = axs[i,j]
                #ax.grid(True)
                ax.plot([years[0],years[-1]], [0,0],'black', linewidth = 0.7)
                domain = state_res_domain[state][res]
                mask = snowmasks[state][res]
                left, right, bottom, top = boundaries[domain][state]
                tmp = partition[state][res][ptype].sel(lat2d = slice(bottom, top),
                                                                           lon2d = slice(left, right))['prec']
                data = np.nanmean(tmp.where(mask), axis = (1,2))[1:-2]
                years = range(1981,2099)
                # ax.plot(years, data, linestyle = ':', alpha = 0.4)
                rolling_yearmean = pd.DataFrame(years).rolling(window = ws).mean()
                rolling_mean = pd.DataFrame(data).rolling(window=ws).mean()
                ax.plot(rolling_yearmean,rolling_mean - np.nanmean(rolling_mean[ws:2*ws]), linestyle = resstyles[l], color = colors[k], alpha = alphas[l], label = gcm.upper())
                lines[gcm][state][res][ptype] = rolling_mean - np.nanmean(rolling_mean[ws:2*ws])
                # ax.hlines(np.nanmean(data[0:20]), 1980, 2100, linewidth = 1)
                ax.set_ylabel(r'$\Delta$' + f'{ptype}'+r' [mm yr$^{-1}$]')
                name = names[state]
                if i == 0: 
                    ax.set_xticklabels([])
                if j == 0: ax.set_ylabel(f'{name}\n'+r'$\Delta $'+f'{ptype}'+r' [mm yr$^{-1}$]')
                if i == 1: ax.set_xlabel('year')

        
        j = 2
        res = '9'
        ax = axs[i,j]
        domain = state_res_domain[state][res]
        mask = snowmasks[state][res]
        left, right, bottom, top = boundaries[domain][state]
        tmpsnow = partition[state][res]['snowfall'].sel(lat2d = slice(bottom, top),
                                                                   lon2d = slice(left, right))['prec']
        tmprain = partition[state][res]['rainfall'].sel(lat2d = slice(bottom, top),
                                                               lon2d = slice(left, right))['prec']
        snowdata = np.nanmean(tmpsnow.where(mask), axis = (1,2))[1:-2]
        raindata = np.nanmean(tmprain.where(mask), axis = (1,2))[1:-2]
        precip = snowdata + raindata
        ws2 = 30
        dprecip = (precip / np.nanmean(precip)) #  - np.nanmean(precip[0:30]))  /  np.nanmean(precip[0:30])
        rollyears = pd.DataFrame(years).rolling(window = ws2).mean()[0].values
        rollsnow = pd.DataFrame(snowdata).rolling(window = ws2).mean()[0].values
        rollrain = pd.DataFrame(raindata).rolling(window = ws2).mean()[0].values
        rolldprecip = pd.DataFrame(dprecip).rolling(window = ws2).mean()[0].values
        rollprecip = pd.DataFrame(precip).rolling(window = ws2).mean()[0].values
        cmap = ccm.roma_r
        x = rollprecip  - np.nanmean(rollprecip[0:30])
        y = rollsnow/rollprecip
        c = np.linspace(0,1,len(rollyears))
        for i in range(len(x) - 1):
            ax.plot(x[i:i+2], y[i:i+2], color=cmap(c[i]), linewidth=2)

        
        if k == 0:
            ax.set_ylabel('proportion snow [-]')
            norm = mcolors.Normalize(vmin=np.nanmin(rollyears), vmax=np.nanmax(rollyears))
            sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
            plt.colorbar(sm, ax =ax)
    
            ax.grid(True)
            ax.set_xlim((-150,150))
            ax.text(1.05,1.02,'year',rotation=0, transform=ax.transAxes, fontsize = 14)        

        
## legend additions
axs[0,0].plot([2000,2000],[0,1], 'k-',label = '9-km', zorder = 0)
axs[0,0].plot([2000,2000],[0,1], 'k--',label = '45-km', zorder = 0)
axs[0,0].plot([2000,2000],[0,1], 'k--',label = '45-km', zorder = 0, alpha = 0)

h, l = axs[0,0].get_legend_handles_labels()
pos = [1,3,5,7,9,11,13,15]
h1 = [h[i] for i in pos]
l1 = [l[i] for i in pos]
for i in range(6): ## add invisible handles and empty labels to make the columns work
    h1.append(h[-1])
    l1.append('')
for i in [16,17]:
    h1.append(h[i])
    l1.append(l[i])
leg = axs[0,0].legend(h1,l1, ncol = 2, fontsize = 12)
axs[0,2].set_xticklabels([])
ax.set_xlabel (r'$\Delta$ total precip [-]')
plt.tight_layout()

for i,ax in enumerate(axs.flatten()): 
    ax.text(0.03, 0.93, chr(i + 97), transform = ax.transAxes)


states = params['states']
ptypes = ['snowfall','rainfall']
for istate, state in enumerate(states):
    for ires,res in enumerate(ress):
        for iptype, ptype in enumerate(ptypes):
            mydata = []
            for gcm in mygcms:
                data = lines[gcm][state][res][ptype]
                mydata.append(data.values.flatten())
            ax = axs[istate,iptype]
            ax.plot(rolling_yearmean, np.nanmean(np.array(mydata), axis = 0), color = 'k', linestyle = resstyles[ires])



plt.savefig('../figures/fig_psnow.jpg', dpi = 400)
plt.show()
# Out:
# /glade/derecho/scratch/mcowherd/tmp/ipykernel_28821/2698691888.py:122: RuntimeWarning: Mean of empty slice
#   ax.plot(rolling_yearmean, np.nanmean(np.array(mydata), axis = 0), color = 'k', linestyle = resstyles[ires])

# %%
states =params['states']
ptypes = ['snowfall','rainfall']
arrs = []
i = 0
for state in states:
    for res in ress:
        for ptype in ptypes:
            list = []
            for gcm in mygcms:
                data = lines[gcm][state][res][ptype]
                list.append(data)
            arr = np.array(list)
            arrs.append(arr)
            print(i, state, res, ptype)
            print(f'mean: {np.nanmean(arr[:,-5], axis = (0))[0]} mm')
            print(f'stdev: {np.nanstd(arr[:,-5], axis = (0))[0]} mm')
            i+=1
# Out:
# 0 CA 45 snowfall
# mean: -82.28692871848742 mm
# stdev: 7.822174614544134 mm
# 1 CA 45 rainfall
# mean: 92.00636914571125 mm
# stdev: 49.91567748963207 mm
# 2 CA 9 snowfall
# mean: -132.65835286935172 mm
# stdev: 14.405014802573335 mm
# 3 CA 9 rainfall
# mean: 130.80981818305122 mm
# stdev: 89.37566999412675 mm
# 4 WY 45 snowfall
# mean: -73.40966571172078 mm
# stdev: 12.03916524904089 mm
# 5 WY 45 rainfall
# mean: 73.4332398308648 mm
# stdev: 40.74819039571615 mm
# 6 WY 9 snowfall
# mean: -74.09085523393418 mm
# stdev: 20.222924769798748 mm
# 7 WY 9 rainfall
# mean: 81.25898224724662 mm
# stdev: 43.072028624358445 mm

# %%
for region in ('SN', 'MR'):
    for var in ('snow', 'rain'):
        s = series[region][var]                       # Nov-Apr volume, mm
        b = float(s.sel(year=slice(1980, 2009)).mean())
        e = float(s.sel(year=slice(2070, 2099)).mean())
        print(f'{region} {var}: baseline {b:.1f} mm, eoc {e:.1f} mm, '
              f'change {e-b:+.1f} mm ({100*(e-b)/b:+.1f}%)')
    sb = float(series[region]['snow'].sel(year=slice(1980, 2009)).mean())
    rb = float(series[region]['rain'].sel(year=slice(1980, 2009)).mean())
    print(f'{region} baseline snow fraction {sb/(sb+rb):.3f}   '
          f'(text says 0.47 SN / 0.48 MR)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 for region in ('SN', 'MR'):
#       2     for var in ('snow', 'rain'):
# ----> 3         s = series[region][var]                       # Nov-Apr volume, mm
#       4         b = float(s.sel(year=slice(1980, 2009)).mean())
#       5         e = float(s.sel(year=slice(2070, 2099)).mean())
#
# NameError: name 'series' is not defined

# %% [markdown]
# SN snowfall (a) decreases by 132 $\pm$ 14 mm in the 9-km resolution but only 82 $\pm$ 8 mm in the 45-km resolution by 2100. % is this because orographic?
# MR snowfall (d) decreases by 74 $\pm$ 20 mm  in the 9-km resolution and 73 $\pm$ 12 mm in the 45-km resolution.

# %% [markdown]
# SN rainfall (b) increases by 130 $\pm$ 89 mm in the 9-km resolution and only 92 $\pm$ 50 mm in the 45-km resolution by 2100.
# MR rainfall (e) increases by 81 $\pm$ 43 in the 9-km resolution and 73 $\pm$ 40 in the 45-km resolution.

# %%
## RELATIVE CHANGES

ws = 15
resstyles = ['--','-']
alphas = [1,1]
colors = ["#332288","#88CCEE","#44AA99","#117733","#999933","#DDCC77","#CC6677","#882255","#AA4499"] #,"brown","fd3c06","gray"]]
fig,axs = plt.subplots(2,3, figsize = (17,10))
regions = {'CA': 'Sierra Nevada',
           'WY': 'Middle Rockies'}

x1s = []
y1s = []
x2s = []
y2s = []

# Storage for ensemble data
ensemble_data = {}

# First pass: collect all data for ensemble statistics
for k,gcm in enumerate(mygcms):
    partition = partitions[k]
    ress = ['45','9']

    var = 'prec'
    for i,state in enumerate(params['states']):
        if state not in ensemble_data:
            ensemble_data[state] = {}
        
        for l,res in enumerate(ress):
            if res not in ensemble_data[state]:
                ensemble_data[state][res] = {'snowfall': [], 'rainfall': []}
                
            for j,ptype in enumerate(['snowfall','rainfall']):
                domain = state_res_domain[state][res]
                mask = snowmasks[state][res]
                left, right, bottom, top = boundaries[domain][state]
                tmp = partition[state][res][ptype].sel(lat2d = slice(bottom, top),
                                                     lon2d = slice(left, right))['prec']
                data = np.nanmean(tmp.where(mask), axis = (1,2))[1:-2]
                years = range(1981,2099)
                
                # Store the rolling mean data for ensemble calculation
                rolling_yearmean = pd.DataFrame(years).rolling(window = ws).mean()
                rolling_mean = pd.DataFrame(data).rolling(window=ws).mean()
                ensemble_data[state][res][ptype].append(100 * (rolling_mean - np.nanmean(rolling_mean[0:3*ws]) )/ np.nanmean(rolling_mean[0:3*ws]))

# Second pass: plot ensemble means with shading
for i,state in enumerate(params['states']):

    yb = []
    yeoc = []
    ress = ['45','9']
    
    for l,res in enumerate(ress):
        for j,ptype in enumerate(['snowfall','rainfall']):
            line_color = '#332288' if res == '9' else '#117733'

            ax = axs[i,j]
            ax.plot([years[0],years[-1]], [0,0],'black', linewidth = 0.7)
            
            # Calculate ensemble statistics
            ensemble_array = np.array([data.values.flatten() for data in ensemble_data[state][res][ptype]])
            ensemble_mean = np.nanmean(ensemble_array, axis=0)
            ensemble_std = np.nanstd(ensemble_array, axis=0)
            
            # Get the corresponding years for plotting
            rolling_yearmean = pd.DataFrame(years).rolling(window = ws).mean().values.flatten()
            
            # Remove NaN values for plotting
            valid_mask = ~np.isnan(ensemble_mean) & ~np.isnan(rolling_yearmean)
            plot_years = rolling_yearmean[valid_mask]
            plot_mean = ensemble_mean[valid_mask]
            plot_std = ensemble_std[valid_mask]

                        # Add shading for standard deviation
            ax.fill_between(plot_years, plot_mean - plot_std, plot_mean + plot_std,
                           alpha=0.2, color=line_color)

            
            # Plot ensemble mean line
            ax.plot(plot_years, plot_mean, linestyle=resstyles[l], color=line_color, 
                   alpha=alphas[l], linewidth=2, label=f'{res}-km')
            
            
            ax.set_ylabel(r'$\Delta$' + f'{ptype}'+r' [%]')
            if i == 0: 
                ax.set_xticklabels([])
            if j == 0: ax.set_ylabel(f'{regions[state]}\n'+r'$\Delta $'+f'{ptype}'+r' [%]')
            if i == 1: ax.set_xlabel('year')

            print (f'{state} {res} {ptype} changes: {np.nanmean(np.array(plot_mean[-30:])-np.array(plot_mean[0:30])):.3f}')
            print (f'std: {np.nanmean(plot_std[-30:]):.3f}')


    # Third column (scatter plot) remains unchanged
    j = 2
    res = '9'
    ax = axs[i,j]
    
    # Only plot for the first GCM to avoid overplotting (or modify as needed)
    for k,gcm in enumerate(mygcms):
        partition = partitions[k]
        domain = state_res_domain[state][res]
        mask = snowmasks[state][res]
        left, right, bottom, top = boundaries[domain][state]
        tmpsnow = partition[state][res]['snowfall'].sel(lat2d = slice(bottom, top),
                                                       lon2d = slice(left, right))['prec']
        tmprain = partition[state][res]['rainfall'].sel(lat2d = slice(bottom, top),
                                                       lon2d = slice(left, right))['prec']
        snowdata = np.nanmean(tmpsnow.where(mask), axis = (1,2))[1:-2]
        raindata = np.nanmean(tmprain.where(mask), axis = (1,2))[1:-2]
        precip = snowdata + raindata
        ws2 = 30
        #dprecip = (precip / np.nanmean(precip))
        
        dprecip = (precip - np.nanmean(precip[0:3*ws]))/ np.nanmean(precip[0:3*ws]) * 100
        rollyears = pd.DataFrame(years).rolling(window = ws2).mean()[0].values
        rollsnow = pd.DataFrame(snowdata).rolling(window = ws2).mean()[0].values
        rollrain = pd.DataFrame(raindata).rolling(window = ws2).mean()[0].values
        rolldprecip = rollsnow + rollrain
        rollddprecip = 100 * (rolldprecip - np.nanmean(rolldprecip[0:ws2])) / np.nanmean(rolldprecip[0:ws2])
        # rolldprecip = pd.DataFrame(dprecip).rolling(window = ws2).mean()[0].values
        # rollprecip = pd.DataFrame(precip).rolling(window = ws2).mean()[0].values
        
        cmap = ccm.roma_r
        x = rollddprecip  # rollprecip  - np.nanmean(rollprecip[0:30])
        y = rollsnow/rollprecip

        yb.append(np.nanmean(y[30:31]))
        yeoc.append(np.nanmean(y[-1:]))
        c = np.linspace(0,1,len(rollyears))
        for idx in range(len(x) - 1):
            ax.plot(x[idx:idx+2], y[idx:idx+2], color=cmap(c[idx]), linewidth=2, alpha=0.9)

    if i in [0,1]:  
        ax.set_ylabel('proportion snow [-]')
        norm = mcolors.Normalize(vmin=np.nanmin(rollyears), vmax=np.nanmax(rollyears))
        sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
        cbar = plt.colorbar(sm, ax=ax)
        ax.text(1.05,1.02,'year',rotation=0, transform=ax.transAxes, fontsize = 14)        
        ax.grid(True)
        ax.set_xlim((-20,20))
    print(f'{state} snow ratio baseline: {np.nanmean(yb):.3f} sd: {np.nanstd(yb):.3f}\n eoc: {np.nanmean(yeoc):.3f}, sd: {np.nanstd(yeoc):.3f}')
    # print (f'{state} changes: {np.nanmean(np.array(yeoc)-np.array(yb)):.3f} and sd : {np.nanstd(np.array(yeoc)-np.array(yb)):.3f}')
    

## Modified legend for ensemble plots
# axs[0,0].plot([2000,2000],[0,1], 'k-', linewidth=2, label='9-km ensemble', zorder=0)
# axs[0,0].plot([2000,2000],[0,1], 'k--', linewidth=2, label='45-km ensemble', zorder=0)
# axs[0,0].fill_between([2000,2000], [0,0], [1,1], alpha=0.2, color='black')

# Get legend handles and labels
h, l = axs[0,0].get_legend_handles_labels()
leg = axs[0,0].legend(h, l, loc='upper right', fontsize=12)

axs[0,2].set_xticklabels([])
ax.set_xlabel(r'$\Delta$ total precip [%]')
plt.tight_layout()

for i, ax in enumerate(axs.flatten()):
    ax.text(0.025, 0.93, chr(97+i), transform=ax.transAxes, fontsize=16)
plt.savefig('../figures/fig_psnow_simple_relative.jpg', dpi = 400)
plt.show()
# Out:
# /glade/derecho/scratch/mcowherd/tmp/ipykernel_28821/3494615365.py:63: RuntimeWarning: Mean of empty slice
#   ensemble_mean = np.nanmean(ensemble_array, axis=0)
# /glade/u/home/mcowherd/.conda/envs/fos/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1878: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# CA 45 snowfall changes: -63.750
# std: 9.570
# CA 45 rainfall changes: 15.260
# std: 10.643
# CA 9 snowfall changes: -49.579
# std: 10.272
# CA 9 rainfall changes: 19.504
# std: 12.224
# CA snow ratio baseline: 0.470 sd: 0.048
#  eoc: 0.232, sd: 0.065
# WY 45 snowfall changes: -31.641
# std: 7.493
# WY 45 rainfall changes: 24.947
# std: 13.066
# WY 9 snowfall changes: -25.884
# std: 7.709
# WY 9 rainfall changes: 24.447
# std: 10.053
# WY snow ratio baseline: 0.479 sd: 0.022
#  eoc: 0.371, sd: 0.052
